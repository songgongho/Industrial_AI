# %% [raw]
# {
#  "cells": [
#   {
#    "cell_type": "markdown",
#    "metadata": {},
#    "source": [
#     "# 01 EDA\n",
#     "\n",
#     "`data_R2.csv`의 구조를 확인하고, 상태 레이블과 이상탐지 모델링에 필요한 기초 분석을 수행하는 노트북입니다.\n"
#    ]
#   },
#   {
#    "cell_type": "code",
#    "execution_count": null,
#    "metadata": {},
#    "outputs": [],
#    "source": [
#     "import pandas as pd\n",
#     "import numpy as np\n",
#     "import matplotlib.pyplot as plt\n",
#     "import seaborn as sns\n",
#     "from pathlib import Path\n",
#     "\n",
#     "DATA_PATH = Path('../data/interim/data_with_header.csv')\n",
#     "if DATA_PATH.exists():\n",
#     "    df = pd.read_csv(DATA_PATH)\n",
#     "else:\n",
#     "    df = pd.read_csv('../data/raw/data_R2.csv', header=None)\n",
#     "df.head()\n"
#    ]
#   },
#   {
#    "cell_type": "markdown",
#    "metadata": {},
#    "source": [
#     "## 분석 섹션\n",
#     "- 컬럼 타입 및 결측치 점검\n",
#     "- 장비별/시간대별 분포\n",
#     "- 상관관계 heatmap\n",
#     "- 알람/이상 샘플 시각화\n"
#    ]
#   },
#   {
#    "cell_type": "code",
#    "execution_count": null,
#    "metadata": {},
#    "outputs": [],
#    "source": [
#     "# TODO: fill with EDA cells\n",
#     "pass\n"
#    ]
#   }
#  ],
#  "metadata": {
#   "kernelspec": {
#    "display_name": "Python 3",
#    "language": "python",
#    "name": "python3"
#   },
#   "language_info": {
#    "name": "python",
#    "version": "3.x"
#   }
#  },
#  "nbformat": 4,
#  "nbformat_minor": 5
# }
